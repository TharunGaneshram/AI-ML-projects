# %%
import numpy as np
import pandas as pd

# %%
#read file data and save to a variable
data = pd.read_csv('CAR DETAILS FROM CAR DEKHO.csv')
print(data)
data.corr().style.background_gradient(cmap="Blues")
# Out:
#         name  year  selling_price  km_driven    fuel seller_type transmission  \
# 0          1  2013        1550000      75800  Diesel      Dealer    Automatic
# 1          1  2017        2750000      13000  Diesel  Individual    Automatic
# 2          1  2012        2500000      48000  Diesel      Dealer    Automatic
# 3          1  2017        2900000      40000  Diesel  Individual    Automatic
# 4          1  2013        2000000     167223  Diesel      Dealer    Automatic
# ...      ...   ...            ...        ...     ...         ...          ...
# 4299  Datsun  2018         400000       4400  Petrol  Individual       Manual
# 4300  Datsun  2018         300000      25000  Petrol  Individual    Automatic
# 4301  Datsun  2015         310000      32686  Petrol      Dealer       Manual
# 4302  Datsun  2017         350000      80000  Petrol  Individual       Manual
# 4303  Datsun  2017         350000      10171  Petrol      Dealer       Manual
#
#       owner  Ave_cost
# 0         2   2945385
# 1         1   2945385
# 2         1   2945385
# 3         1   2945385
# 4         1   2945385
# ...     ...       ...
# 4299      2    297027
# 4300      1    297027
# 4301      1    297027
# 4302      1    297027
# 4303      1    297027
#
# [4304 rows x 9 columns]
# <style type="text/css">
# #T_b3d7f_row0_col0, #T_b3d7f_row1_col1, #T_b3d7f_row2_col2, #T_b3d7f_row3_col3, #T_b3d7f_row4_col4 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_b3d7f_row0_col1 {
#   background-color: #65aad4;
#   color: #f1f1f1;
# }
# #T_b3d7f_row0_col2, #T_b3d7f_row0_col3, #T_b3d7f_row2_col0, #T_b3d7f_row2_col1, #T_b3d7f_row3_col1, #T_b3d7f_row3_col4 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_b3d7f_row0_col4 {
#   background-color: #e2edf8;
#   color: #000000;
# }
# #T_b3d7f_row1_col0 {
#   background-color: #4d99ca;
#   color: #f1f1f1;
# }
# #T_b3d7f_row1_col2 {
#   background-color: #d9e7f5;
#   color: #000000;
# }
# #T_b3d7f_row1_col3 {
#   background-color: #dae8f6;
#   color: #000000;
# }
# #T_b3d7f_row1_col4 {
#   background-color: #2d7dbb;
#   color: #f1f1f1;
# }
# #T_b3d7f_row2_col3 {
#   background-color: #71b1d7;
#   color: #f1f1f1;
# }
# #T_b3d7f_row2_col4 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_b3d7f_row3_col0 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_b3d7f_row3_col2 {
#   background-color: #6fb0d7;
#   color: #f1f1f1;
# }
# #T_b3d7f_row4_col0 {
#   background-color: #a9cfe5;
#   color: #000000;
# }
# #T_b3d7f_row4_col1 {
#   background-color: #2272b6;
#   color: #f1f1f1;
# }
# #T_b3d7f_row4_col2 {
#   background-color: #b8d5ea;
#   color: #000000;
# }
# #T_b3d7f_row4_col3 {
#   background-color: #c4daee;
#   color: #000000;
# }
# </style>
# <table id="T_b3d7f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b3d7f_level0_col0" class="col_heading level0 col0" >year</th>
#       <th id="T_b3d7f_level0_col1" class="col_heading level0 col1" >selling_price</th>
#       <th id="T_b3d7f_level0_col2" class="col_heading level0 col2" >km_driven</th>
#       <th id="T_b3d7f_level0_col3" class="col_heading level0 col3" >owner</th>
#       <th id="T_b3d7f_level0_col4" class="col_heading level0 col4" >Ave_cost</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b3d7f_level0_row0" class="row_heading level0 row0" >year</th>
#       <td id="T_b3d7f_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_b3d7f_row0_col1" class="data row0 col1" >0.421184</td>
#       <td id="T_b3d7f_row0_col2" class="data row0 col2" >-0.419649</td>
#       <td id="T_b3d7f_row0_col3" class="data row0 col3" >-0.407686</td>
#       <td id="T_b3d7f_row0_col4" class="data row0 col4" >0.065448</td>
#     </tr>
#     <tr>
#       <th id="T_b3d7f_level0_row1" class="row_heading level0 row1" >selling_price</th>
#       <td id="T_b3d7f_row1_col0" class="data row1 col0" >0.421184</td>
#       <td id="T_b3d7f_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_b3d7f_row1_col2" class="data row1 col2" >-0.200648</td>
#       <td id="T_b3d7f_row1_col3" class="data row1 col3" >-0.201714</td>
#       <td id="T_b3d7f_row1_col4" class="data row1 col4" >0.692999</td>
#     </tr>
#     <tr>
#       <th id="T_b3d7f_level0_row2" class="row_heading level0 row2" >km_driven</th>
#       <td id="T_b3d7f_row2_col0" class="data row2 col0" >-0.419649</td>
#       <td id="T_b3d7f_row2_col1" class="data row2 col1" >-0.200648</td>
#       <td id="T_b3d7f_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_b3d7f_row2_col3" class="data row2 col3" >0.274491</td>
#       <td id="T_b3d7f_row2_col4" class="data row2 col4" >-0.000651</td>
#     </tr>
#     <tr>
#       <th id="T_b3d7f_level0_row3" class="row_heading level0 row3" >owner</th>
#       <td id="T_b3d7f_row3_col0" class="data row3 col0" >-0.407686</td>
#       <td id="T_b3d7f_row3_col1" class="data row3 col1" >-0.201714</td>
#       <td id="T_b3d7f_row3_col2" class="data row3 col2" >0.274491</td>
#       <td id="T_b3d7f_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_b3d7f_row3_col4" class="data row3 col4" >-0.047867</td>
#     </tr>
#     <tr>
#       <th id="T_b3d7f_level0_row4" class="row_heading level0 row4" >Ave_cost</th>
#       <td id="T_b3d7f_row4_col0" class="data row4 col0" >0.065448</td>
#       <td id="T_b3d7f_row4_col1" class="data row4 col1" >0.692999</td>
#       <td id="T_b3d7f_row4_col2" class="data row4 col2" >-0.000651</td>
#       <td id="T_b3d7f_row4_col3" class="data row4 col3" >-0.047867</td>
#       <td id="T_b3d7f_row4_col4" class="data row4 col4" >1.000000</td>
#     </tr>
#   </tbody>
# </table>
